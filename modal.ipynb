# %%
# %pip install pandas scikit-learn matplotlib graphviz
# Out:
# Requirement already satisfied: pandas in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.5)
# Requirement already satisfied: scikit-learn in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.9.0)
# Requirement already satisfied: matplotlib in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.1)
# Requirement already satisfied: graphviz in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.21)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Star Computer\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Star Computer\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Star Computer\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
dataset=pd.read_csv('Iris.csv')
dataset.drop(columns=['Id'], inplace=True)

# %%
dataset.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(dataset.isnull().sum())
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

dataset.plot(kind='line', figsize=(10,6))

plt.title("Line Plot of All Columns")
plt.xlabel("Index")
plt.ylabel("Values")
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset['Species'] = le.fit_transform(dataset['Species'])

# %%
import pickle
with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(le, f)
X = dataset.drop(columns=['Species'])
y= dataset['Species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
clf = DecisionTreeClassifier(criterion="gini", max_depth=3, random_state=42)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
y_pred = clf.predict(X_test)

# Step 7: Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9333333333333333

# %%
le.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(10,10))
tree.plot_tree(
    clf, 
    feature_names=X.columns, 
    class_names=le.classes_,  # convert to strings
    filled=True
)
plt.show()

# %%
# Take Predictuion on Single Data Point
# Sepal Length, Sepal Width, Petal Length, Petal Width
single_data = [[5.1, 3.5, 3, 0.2]]
predicted_class = clf.predict(single_data)
print("Predicted class for single data point:", le.inverse_transform(predicted_class))
# Out:
# Predicted class for single data point: ['Iris-versicolor']
# c:\Users\Star Computer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd

# Feature importance
feat_importance = pd.Series(clf.feature_importances_, index=X.columns)

# Plot
feat_importance.sort_values().plot(kind='barh', color="skyblue")
plt.title("Feature Importance in Decision Tree")
plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# Confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred,
                                        display_labels=le.classes_,
                                        cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
import pickle
# Exporting the trained model
with open('decision_tree_model.pkl', 'wb') as f:
    pickle.dump(clf, f)
